# %% [markdown]
# <a href="https://colab.research.google.com/github/AenimaLabs/Oracle_One_Data_Science/blob/main/Visualizaci%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualización de datos con python:
# * Matplotlib
# * Seaborn
# * Plotly

# %% [markdown]
# ##Preparando datos:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

ruta = "/content/drive/MyDrive/Data Science Oracle One/canadian_immegration_data.csv"
inmigracion = pd.read_csv(ruta)

display(inmigracion)
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
inmigracion.isnull().sum() #isna().sum() hace lo mismo, is not available
# Out:
# Country      0
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
inmigracion.shape
# Out:
# (195, 39)

# %%
inmigracion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    195 non-null    object
#  1   Continent  195 non-null    object
#  2   Region     195 non-null    object
#  3   DevName    195 non-null    object
#  4   1980       195 non-null    int64
#  5   1981       195 non-null    int64
#  6   1982       195 non-null    int64
#  7   1983       195 non-null    int64
#  8   1984       195 non-null    int64
#  9   1985       195 non-null    int64
#  10  1986       195 non-null    int64
#  11  1987       195 non-null    int64
#  12  1988       195 non-null    int64
#  13  1989       195 non-null    int64
#  14  1990       195 non-null    int64
#  15  1991       195 non-null    int64
#  16  1992       195 non-null    int64
#  17  1993       195 non-null    int64
#  18  1994       195 non-null    int64
#  19  1995       195 non-null    int64
# ...

# %%
inmigracion.set_index("Country", inplace=True) #el indice es ahora el país

# %%
display(inmigracion)
# Out:
#                Continent              Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
years = list(map(str, range(1980, 2014))) #incluye el primer número, excluye el segundo número
display(years)
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
colombia = inmigracion.loc["Colombia", years]
display(colombia)
# Out:
# 1980     266
# 1981     326
# 1982     360
# 1983     244
# 1984     235
# 1985     214
# 1986     257
# 1987     376
# 1988     352
# 1989     439
# 1990     614
# 1991     652
# 1992     582
# 1993     464
# 1994     375
# 1995     371
# 1996     381
# 1997     578
# 1998     929
# 1999    1306
# 2000    2259
# 2001    2965
# 2002    3283
# 2003    4318
# 2004    4566
# 2005    6424
# 2006    6535
# 2007    5357
# 2008    5452
# 2009    4652
# 2010    5218
# 2011    4366
# 2012    3741
# 2013    3631
# Name: Colombia, dtype: object

# %%
# col_dict = colombia.to_dict()
col_dict = {"Año": colombia.index.to_list(),
            "Inmigrantes": colombia.values.tolist()}
display(col_dict)
# Out:
# {'Año': ['1980',
#   '1981',
#   '1982',
#   '1983',
#   '1984',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013'],
#  'Inmigrantes': [np.int64(266),
#   np.int64(326),
#   np.int64(360),
#   np.int64(244),
#   np.int64(235),
#   np.int64(214),
#   np.int64(257),
#   np.int64(376),
#   np.int64(352),
#   np.int64(439),
#   np.int64(614),
#   np.int64(652),
#   np.int64(582),
#   np.int64(464),
#   np.int64(375),
#   np.int64(371),
#   np.int64(381),
#   np.int64(578),
#   np.int64(929),
#   np.int64(1306),
#   np.int64(2259),
#   np.int64(2965),
#   np.int64(3283),
#   np.int64(4318),
#   np.int64(4566),
#   np.int64(6424),
#   np.int64(6535),
#   np.int64(5357),
#   np.int64(5452),
# ...

# %%
datos_col = pd.DataFrame(col_dict)
display(datos_col)
# Out:
#      Año  Inmigrantes
# 0   1980          266
# 1   1981          326
# 2   1982          360
# 3   1983          244
# 4   1984          235
# 5   1985          214
# 6   1986          257
# 7   1987          376
# 8   1988          352
# 9   1989          439
# 10  1990          614
# 11  1991          652
# 12  1992          582
# 13  1993          464
# 14  1994          375
# 15  1995          371
# 16  1996          381
# 17  1997          578
# 18  1998          929
# 19  1999         1306
# 20  2000         2259
# 21  2001         2965
# 22  2002         3283
# 23  2003         4318
# 24  2004         4566
# 25  2005         6424
# 26  2006         6535
# 27  2007         5357
# 28  2008         5452
# 29  2009         4652
# 30  2010         5218
# 31  2011         4366
# 32  2012         3741
# 33  2013         3631

# %% [markdown]
# ##Matplotlib:
# [Documentación oficial](https://matplotlib.org/)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5)) #tamaño de la figura 10 pulgadas por 5 pulgadas
plt.plot(datos_col["Año"], datos_col["Inmigrantes"]) #plot hace un gráfico de línea
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010', '2013'])
plt.title("Inmigrantes de Colombia a Canadá")
plt.xlabel("Año")
plt.ylabel("Inmigrantes")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
ax.plot(datos_col["Año"], datos_col["Inmigrantes"])
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #los ticks van de 5 en 5 de manera automática
ax.set_title("Inmigrantes de Colombia a Canadá\n1980 - 2013")
ax.set_xlabel("Año")
ax.set_ylabel("Inmigrantes")
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,3))
axs[0].plot(datos_col["Año"], datos_col["Inmigrantes"])
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].set_title("Inmigrantes de Colombia a Canadá\n1980 - 2013")
axs[0].set_xlabel("Año")
axs[0].set_ylabel("Inmigrantes")
axs[0].grid(True)

axs[1].boxplot(datos_col["Inmigrantes"])
axs[1].set_title("Distribución de los datos")
axs[1].set_ylabel("Inmigrantes")
axs[1].set_xlabel("Colombia")
axs[1].grid(True)

plt.show()


plt.show()

# %%
datos_col.describe()
# Out:
#        Inmigrantes
# count    34.000000
# mean   2120.235294
# std    2163.761316
# min     214.000000
# 25%     372.000000
# 50%     633.000000
# 75%    4173.750000
# max    6535.000000

# %%
fig, axs = plt.subplots(2, 2, figsize=(10,6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle("Distribución de los datos", fontsize=16)

axs[0, 0].plot(inmigracion.loc["Colombia", years])
axs[0, 0].set_title("Inmigrantes de Colombia a Canadá\n1980 - 2013")


axs[0, 1].plot(inmigracion.loc["Brazil", years])
axs[0, 1].set_title("Inmigrantes de Brasil a Canadá\n1980 - 2013")


axs[1, 0].plot(inmigracion.loc["Argentina", years])
axs[1, 0].set_title("Inmigrantes de Argentina a Canadá\n1980 - 2013")


axs[1, 1].plot(inmigracion.loc["Chile", years])
axs[1, 1].set_title("Inmigrantes de Chile a Canadá\n1980 - 2013")

ymin = 0
ymax = 7000

for ax in axs.ravel():
    ax.set_ylim(ymin, ymax)




for ax in axs.flat:
    ax.xaxis.set_major_locator(plt.MultipleLocator(5))
    ax.set_xlabel("Año")
    ax.set_ylabel("Inmigrantes")
    ax.grid(True)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 3)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
ax.plot(datos_col["Año"], datos_col["Inmigrantes"], lw=2, marker="o")
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #los ticks van de 5 en 5 de manera automática
ax.set_title("Inmigrantes de Colombia a Canadá\n1980 - 2013", fontsize=20, loc="left")
ax.set_xlabel("Año", fontsize=14)
ax.set_ylabel("Inmigrantes",fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
ax.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 3)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
ax.plot(datos_col["Año"], datos_col["Inmigrantes"], lw=2.5, marker="o", color = "g")
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #los ticks van de 5 en 5 de manera automática
ax.set_title("Inmigrantes de Colombia a Canadá\n1980 - 2013", fontsize=20, loc="left")
ax.set_xlabel("Año", fontsize=14)
ax.set_ylabel("Inmigrantes",fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
ax.grid(linestyle = '--')
plt.show()

# %%
print(plt.style.available) #estilos disponibles
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
IPython_default = plt.rcParams.copy()
#para evitar que el estilo se aplique a todos los gráficos trazados en el mismo notebook,
#podemos utilizar un código que crea una copia de las configuraciones predeterminadas de trazado

# %%
plt.style.use('fivethirtyeight')
#se basa en un sitio de noticias y análisis de datos llamado

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(datos_col['Año'], datos_col['Inmigrantes'])
ax.set_title('Inmigración de colombianos hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_ylabel('Número de Inmigrantes', fontsize=14)
ax.set_xlabel('Año', fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %%
plt.rcParams.update(IPython_default);
#¿y si queremos trazar gráficos sin este estilo después de haberlo definido en el notebook?

# %%
#  podemos aplicar un estilo solo a un bloque de código específico,
#  ya que el paquete de estilo proporciona un administrador de contexto para limitar sus cambios a un ámbito específico.
#  Para aislar tus cambios de estilo, puedes escribir el código dentro de un contexto with

with plt.style.context('fivethirtyeight'):
  fig, ax = plt.subplots(figsize=(8, 4))
  ax.plot(datos_col['Año'], datos_col['Inmigrantes'])
  ax.set_title('Inmigración de colombianos hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
  ax.set_ylabel('Número de Inmigrantes', fontsize=14)
  ax.set_xlabel('Año', fontsize=14)
  ax.yaxis.set_tick_params(labelsize=12)
  ax.xaxis.set_tick_params(labelsize=12)
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  plt.show()

# %%
sudamerica = inmigracion.query("Region == 'South America'")
display(sudamerica)
# Out:
#                                                           Continent  \
# Country
# Argentina                           Latin America and the Caribbean
# Bolivia (Plurinational State of)    Latin America and the Caribbean
# Brazil                              Latin America and the Caribbean
# Chile                               Latin America and the Caribbean
# Colombia                            Latin America and the Caribbean
# Ecuador                             Latin America and the Caribbean
# Guyana                              Latin America and the Caribbean
# Paraguay                            Latin America and the Caribbean
# Peru                                Latin America and the Caribbean
# Suriname                            Latin America and the Caribbean
# Uruguay                             Latin America and the Caribbean
# Venezuela (Bolivarian Republic of)  Latin America and the Caribbean
#
# ...

# %%
# Create a copy of the DataFrame to avoid SettingWithCopyWarning
sudamerica = inmigracion.query("Region == 'South America'").copy()

# Correct the index names
sudamerica = sudamerica.rename(index={"Bolivia (Plurinational State of)": "Bolivia",
                                       "Venezuela (Bolivarian Republic of)": "Venezuela",
                                       "Falkland Islands (Malvinas)": "Falkland Islands"})

# %%
colores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12, 5))
ax.bar(sudamerica.index, sudamerica['Total'], color=colores)
ax.set_title('Inmigración Sudamericana hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_xlabel('')
ax.set_ylabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
colores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(sudamerica.index, sudamerica['Total'], color=colores)
ax.set_title('Inmigración Sudamericana hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_ylabel('')
ax.set_xlabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
sudamerica_sorted = sudamerica.sort_values(by='Total', ascending=True)

colores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color=colores)
ax.set_title('Inmigración Sudamericana hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_ylabel('')
ax.set_xlabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

plt.savefig('/content/drive/MyDrive/Data Science Oracle One/inmigrantes_sudamericanos.png', transparent = False,dpi=300, bbox_inches='tight')

plt.show()

# %%
display(sudamerica_sorted)
# Out:
#                                  Continent         Region             DevName  \
# Country
# Suriname   Latin America and the Caribbean  South America  Developing regions
# Paraguay   Latin America and the Caribbean  South America  Developing regions
# Bolivia    Latin America and the Caribbean  South America  Developing regions
# Uruguay    Latin America and the Caribbean  South America  Developing regions
# Ecuador    Latin America and the Caribbean  South America  Developing regions
# Argentina  Latin America and the Caribbean  South America  Developing regions
# Venezuela  Latin America and the Caribbean  South America  Developing regions
# Chile      Latin America and the Caribbean  South America  Developing regions
# Brazil     Latin America and the Caribbean  South America  Developing regions
# Peru       Latin America and the Caribbean  South America  Developing regions
# Colombia   Latin America and the Caribbean  South America  Developing regions
# ...

# %%
colores = []
for pais in sudamerica_sorted.index:
    if pais == 'Chile':
      colores.append('forestgreen')
    else:
      colores.append('silver')

fig, ax = plt.subplots(figsize=(12, 5))
ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color=colores)
ax.set_title('Inmigración de Chilenos hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_ylabel('')
ax.set_xlabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.show()

# %%
colores = []
for pais in sudamerica_sorted.index:
    if pais == 'Chile':
      colores.append('forestgreen')
    else:
      colores.append('silver')

fig, ax = plt.subplots(figsize=(12, 5))

ax.set_frame_on(False)
ax.xaxis.set_visible(False)
ax.tick_params(axis = "y", which = "both", size = 0)




ax.barh(sudamerica_sorted.index, sudamerica_sorted['Total'], color=colores)
ax.set_title('Inmigración de Chilenos hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_ylabel('')
# ax.set_xlabel('Número de Inmigrantes', fontsize=14)
# ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i, j in enumerate(sudamerica_sorted['Total']):
    ax.text(j, i, str(j), color = "red",ha='left', va='center', fontsize=12)

plt.show()

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
with plt.style.context('fivethirtyeight'):
  fig, ax = plt.subplots(figsize=(8, 4))
  ax.plot(datos_col['Año'], datos_col['Inmigrantes'])
  ax.set_title('Inmigración de colombianos hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
  ax.set_ylabel('Número de Inmigrantes', fontsize=14)
  ax.set_xlabel('Año', fontsize=14)
  ax.yaxis.set_tick_params(labelsize=12)
  ax.xaxis.set_tick_params(labelsize=12)
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  plt.savefig('colombia.png', dpi=300)

  plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 3)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
ax.plot(datos_col["Año"], datos_col["Inmigrantes"], lw=2.5, marker="o", color = "g")
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #los ticks van de 5 en 5 de manera automática
ax.set_title("Inmigrantes de Colombia a Canadá\n1980 - 2013", fontsize=20, loc="left")
ax.set_xlabel("Año", fontsize=14)
ax.set_ylabel("Inmigrantes",fontsize=14)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.savefig('/content/drive/MyDrive/Data Science Oracle One/colombia_sin_grid.png', transparent = False,dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ##Seaborn:
# [Documentación oficial](https://seaborn.pydata.org/)

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
top_10 = inmigracion.sort_values(by='Total', ascending=False).head(10)
display(top_10)
# Out:
#                                                            Continent  \
# Country
# India                                                           Asia
# China                                                           Asia
# United Kingdom of Great Britain and Northern Ir...            Europe
# Philippines                                                     Asia
# Pakistan                                                        Asia
# United States of America                            Northern America
# Iran (Islamic Republic of)                                      Asia
# Sri Lanka                                                       Asia
# Republic of Korea                                               Asia
# Poland                                                        Europe
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# ...

# %%
sns.barplot(data=top_10, x='Total', y=top_10.index, orient="h")
plt.show()

# %%
# Correct the index names
top_10 = top_10.rename(index={"United Kingdom of Great Britain and Northern Ireland": "Great Britain"})
display(top_10)
# Out:
#                                    Continent              Region  \
# Country
# India                                   Asia       Southern Asia
# China                                   Asia        Eastern Asia
# Great Britain                         Europe     Northern Europe
# Philippines                             Asia  South-Eastern Asia
# Pakistan                                Asia       Southern Asia
# United States of America    Northern America    Northern America
# Iran (Islamic Republic of)              Asia       Southern Asia
# Sri Lanka                               Asia       Southern Asia
# Republic of Korea                       Asia        Eastern Asia
# Poland                                Europe      Eastern Europe
#
#                                        DevName   1980   1981   1982   1983  \
# Country
# India                       Developing regions   8880   8670   8147   7338
# China                       Developing regions   5123   6682   3308   1863
# ...

# %%
ax = sns.barplot(data=top_10, x='Total', y=top_10.index, orient="h")
ax.set_title('Top 10 países con más inmigración hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_xlabel('Número de Inmigrantes', fontsize=14)
ax.set_ylabel('Año')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 3)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
ax = sns.barplot(data=top_10, x='Total', y=top_10.index, orient="h")
ax.set_title('Top 10 países con más inmigración hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
ax.set_xlabel('Número de Inmigrantes', fontsize=14)
ax.set_ylabel('')
plt.show()

# %%
def generar_grafico (palette):
  fig, ax = plt.subplots(figsize=(10, 3)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
  ax = sns.barplot(data=top_10, x='Total', hue=top_10.index, orient="h", palette=palette)
  ax.set_title('Top 10 países con más inmigración hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
  ax.set_xlabel('Número de Inmigrantes', fontsize=14)
  ax.set_ylabel('')
  plt.show()

# %%
generar_grafico("Blues_r")

# %%
def generar_grafico (palette):
  fig, ax = plt.subplots(figsize=(10, 3)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
  ax.set_frame_on(False)
  ax.xaxis.set_visible(False)
  ax.tick_params(axis = "y", which = "both", size = 0)
  ax = sns.barplot(data=top_10, x='Total', y=top_10.index , hue=top_10.index, orient="h", palette=palette, legend=False)
  ax.set_title('Top 10 países con más inmigración hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
  ax.set_xlabel('Número de Inmigrantes', fontsize=14)
  ax.set_ylabel('')
  for i, j in enumerate(top_10['Total']):
    ax.text(j, i, str(j), color = "black",ha='left', va='center', fontsize=12)
  plt.show()

# %%
generar_grafico("Blues_r")

# %%
generar_grafico("rocket")

# %%
generar_grafico("Paired")

# %%
generar_grafico("tab10")

# %%
def generar_grafico (palette):
  fig, ax = plt.subplots(figsize=(10, 3)) #fig es la figura (tamaño del lienzo) y ax es la gráfica
  ax.set(xticklabels = [])
  ax = sns.barplot(data=top_10, x='Total', y=top_10.index , hue=top_10.index, orient="h", palette=palette, legend=False)
  ax.set_title('Top 10 países con más inmigración hacia Canadá\n1980 a 2013', fontsize=20, loc='left')
  ax.set_xlabel('Número de Inmigrantes', fontsize=14)
  ax.set_ylabel('')
  sns.despine()
  for i, j in enumerate(top_10['Total']):
    ax.text(j, i, str(j), color = "black",ha='left', va='center', fontsize=12)
  plt.show()

# %%
sns.set_theme(style="darkgrid")
generar_grafico("tab10")

# %%
sns.set_theme(style="white")
generar_grafico("tab10")

# %%
sns.set_theme()
sns.set_palette('Dark2')

fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(inmigracion.loc['Brazil', years], label='Brazil', lw=3)
ax = sns.lineplot(inmigracion.loc['Argentina', years], label='Argentina', lw=3)
ax = sns.lineplot(inmigracion.loc['Peru', years], label='Perú', lw=3)
ax = sns.lineplot(inmigracion.loc['Colombia', years], label='Colombia', lw=3)

ax.set_title('Inmigración de los principales países de América del Sur\nal Canadá de 1980 a 2013', loc='left', fontsize=20)
ax.set_xlabel('Año', fontsize=14)
ax.set_ylabel('Número de Inmigrantes', fontsize=14)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.legend(title='Países', loc='upper right', bbox_to_anchor=(1.18, 1.02))

plt.show()

# %% [markdown]
# ##Plotly
# [Documentación oficial](https://plotly.com/python//)

# %%
import plotly.express as px

# %%
fig = px.line(datos_col, x='Año', y='Inmigrantes', title='Inmigración de Colombia a Canadá\n1980 a 2013')
fig.update_traces(line_color = 'green', line_width = 3)
fig.update_layout(width = 600, height = 400, xaxis = {'tickangle':-45},
                  xaxis_title= 'Año',
                  yaxis_title = 'Número Inmigrantes',
                  font_family = 'Arial',
                  font_size= 14,
                  font_color = 'grey')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
display(sudamerica.head(3))
# Out:
#                                  Continent         Region             DevName  \
# Country
# Argentina  Latin America and the Caribbean  South America  Developing regions
# Bolivia    Latin America and the Caribbean  South America  Developing regions
# Brazil     Latin America and the Caribbean  South America  Developing regions
#
#            1980  1981  1982  1983  1984  1985  1986  ...  2005  2006  2007  \
# Country                                              ...
# Argentina   368   426   626   241   237   196   213  ...  1153   847   620
# Bolivia      44    52    42    49    38    44    79  ...   134   139   107
# Brazil      211   220   192   139   145   130   205  ...   969  1181  1746
#
#            2008  2009  2010  2011  2012  2013  Total
# Country
# Argentina   540   467   459   278   263   282  19596
# Bolivia     143   214   180    86    83   107   3205
# Brazil     2138  2509  2598  1508  1642  1714  29659
#
# [3 rows x 38 columns]

# %%
sudamerica.drop(['Continent', 'Region', 'Total', 'DevName'], axis=1, inplace=True)
display(sudamerica.head(3))
# Out:
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                                ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
# Bolivia      44    52    42    49    38    44    79   165    63    68  ...
# Brazil      211   220   192   139   145   130   205   244   394   650  ...
#
#            2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Argentina  1591  1153   847   620   540   467   459   278   263   282
# Bolivia      85   134   139   107   143   214   180    86    83   107
# Brazil      917   969  1181  1746  2138  2509  2598  1508  1642  1714
#
# [3 rows x 34 columns]

# %%
sudamerica = sudamerica.T
display(sudamerica.head(3))
# Out:
# Country  Argentina  Bolivia  Brazil  Chile  Colombia  Ecuador  Guyana  \
# 1980           368       44     211   1233       266      238    2334
# 1981           426       52     220   1069       326      207    2943
# 1982           626       42     192   1078       360      184    3575
#
# Country  Paraguay  Peru  Suriname  Uruguay  Venezuela
# 1980           45   317        15      128        103
# 1981           26   456        10      132        117
# 1982           32   401        21      146        174

# %%
fig = px.line(sudamerica, x=sudamerica.index, y= sudamerica.columns,
              title='Inmigración de Sudamericanos a Canadá\n1980 a 2013',
              color = 'Country',
              markers=True)
fig.update_layout(xaxis = {'tickangle':-45},
                  xaxis_title= 'Año',
                  yaxis_title = 'Número Inmigrantes',
                  font_family = 'Arial',
                  font_size= 14,
                  font_color = 'grey')
fig.write_html('/content/drive/MyDrive/Data Science Oracle One/inmigracion_sud_canada.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
display(datos_col.head())
# Out:
#     Año  Inmigrantes
# 0  1980          266
# 1  1981          326
# 2  1982          360
# 3  1983          244
# 4  1984          235

# %%
import plotly.graph_objs as go

datos_col['Año'] = datos_col['Año'].astype(int)

# Criando uma figura
fig = go.Figure()

# Adicionando a linha do gráfico e definindo a espessura da linha
fig.add_trace(
    go.Scatter(x=[datos_col['Año'].iloc[0]], y=[datos_col['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes', line=dict(width=4))
)

# Definir la configuración del layout
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Colombianos hacia Canadá en el periodo de 1980 a 2013</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 7000], autorange=False, title='<b>Número de Inmigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1000,
    height=500
)

# Definir la configuración de la animación
frames = [go.Frame(data=[go.Scatter(x=datos_col['Año'].iloc[:i+1], y=datos_col['Inmigrantes'].iloc[:i+1])]) for i in range(len(datos_col))]
fig.frames = frames

# Mostrar la figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
brasil = inmigracion.loc['Brazil', years]
argentina = inmigracion.loc['Argentina', years]

# %%
bra_dict = {'Año': brasil.index.to_list(),
            'Inmigrantes': brasil.values.tolist()}
arg_dict = {'Año': argentina.index.to_list(),
            'Inmigrantes': argentina.values.tolist()}

# %%
datos_brasil = pd.DataFrame(bra_dict)
datos_argentina = pd.DataFrame(arg_dict)

datos_brasil['Año'] = datos_col['Año'].astype(int)
datos_argentina['Año'] = datos_col['Año'].astype(int)

# %%
display(datos_brasil.head())
display(datos_argentina.head())
# Out:
#     Año  Inmigrantes
# 0  1980          211
# 1  1981          220
# 2  1982          192
# 3  1983          139
# 4  1984          145
#     Año  Inmigrantes
# 0  1980          368
# 1  1981          426
# 2  1982          626
# 3  1983          241
# 4  1984          237

# %%
import plotly.graph_objs as go

# Creando una figura
fig = go.Figure()

# Agregando la línea con los datos de Brasil
fig.add_trace(
    go.Scatter(x=[datos_brasil['Año'].iloc[0]], y=[datos_brasil['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes de Brasil', line=dict(width=4))
)

# Agregando la línea con los datos de Argentina
fig.add_trace(
    go.Scatter(x=[datos_argentina['Año'].iloc[0]], y=[datos_argentina['Inmigrantes'].iloc[0]], mode='lines', name='Inmigrantes de Argentina', line=dict(width=4))
)

# Definiendo las configuraciones de diseño
fig.update_layout(
    title=dict(
        text='<b>Inmigración de Brasil y Argentina a Canadá en el período de 1980 a 2013</b>',
        x=0.1,
        font=dict(size=18)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Año</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de inmigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1200, # Ancho de la figura en píxeles
    height=600 # Altura de la figura en píxeles
)

# Definiendo las configuraciones de animación
frames = []
for i in range(len(datos_brasil)):
    frame_data = [
        go.Scatter(x=datos_brasil['Año'].iloc[:i+1], y=datos_brasil['Inmigrantes'].iloc[:i+1]),
        go.Scatter(x=datos_argentina['Año'].iloc[:i+1], y=datos_argentina['Inmigrantes'].iloc[:i+1])
    ]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

# Mostrando la figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Práctica

# %%
df_comparacion = inmigracion.loc[['Brazil', 'Argentina'], years]
df_comparacion
# Out:
#            1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                                ...
# Brazil      211   220   192   139   145   130   205   244   394   650  ...
# Argentina   368   426   626   241   237   196   213   519   374   538  ...
#
#            2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Brazil      917   969  1181  1746  2138  2509  2598  1508  1642  1714
# Argentina  1591  1153   847   620   540   467   459   278   263   282
#
# [2 rows x 34 columns]

# %%
df_comparacion = df_comparacion.T #T de transpose
df_comparacion
# Out:
# Country  Brazil  Argentina
# 1980        211        368
# 1981        220        426
# 1982        192        626
# 1983        139        241
# 1984        145        237
# 1985        130        196
# 1986        205        213
# 1987        244        519
# 1988        394        374
# 1989        650        538
# 1990        650        678
# 1991        877        763
# 1992       1066       1023
# 1993        866       1022
# 1994        566        366
# 1995        572        380
# 1996        586        396
# 1997        591        391
# 1998        531        349
# 1999        626        318
# 2000        845        427
# 2001        847        635
# 2002        745        865
# 2003        839       1745
# 2004        917       1591
# 2005        969       1153
# 2006       1181        847
# 2007       1746        620
# 2008       2138        540
# 2009       2509        467
# 2010       2598        459
# 2011       1508        278
# 2012       1642        263
# ...

# %%
plt.plot(df_comparacion['Brazil'], label='Brazil')
plt.plot(df_comparacion['Argentina'], label='Argentina')
plt.title('Inmigración de Brasil y Argentina a Canadá')
plt.xlabel('Año')
plt.ylabel('Número de Inmigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.legend()
plt.show()

# %%
tiendas = ['A', 'B', 'C', 'D']
ventas_2022 = {'Ene': [100, 80, 150, 50],
    'Feb': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'May': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Sep': [240, 160, 290, 130],
    'Oct': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dec': [300, 350, 400, 250]}

# %%
ventas_tiendas = pd.DataFrame(ventas_2022, index=tiendas)
ventas_tiendas
# Out:
#    Ene  Feb  Mar  Abr  May  Jun  Jul  Ago  Sep  Oct  Nov  Dec
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
# Crear la figura y los subgráficos

fig, axs = plt.subplots(2, 2, figsize=(14, 8))

# Ajustar los espaciados entre los subgráficos

plt.subplots_adjust(wspace=0.3, hspace=0.4)

# Agregar un título general para los subgráficos

fig.suptitle('Ventas en el período de enero a diciembre de 2022 en las tiendas A, B, C y D')

# Agregar los gráficos en cada uno de los subgráficos

axs[0, 0].plot(ventas_tiendas.loc['A'])
axs[0, 0].set_title('Ventas en la tienda A')
axs[0, 1].plot(ventas_tiendas.loc['B'])
axs[0, 1].set_title('Ventas en la tienda B')
axs[1, 0].plot(ventas_tiendas.loc['C'])
axs[1, 0].set_title('Ventas en la tienda C')
axs[1, 1].plot(ventas_tiendas.loc['D'])
axs[1, 1].set_title('Ventas en la tienda D')

# Agregar etiquetas para los ejes X y Y

for ax in axs.flat:
    ax.set_xlabel('Mes')
    ax.set_ylabel('Número de ventas')

# Mostrar la figura

plt.show()

# %%
# Crear la figura y los subgráficos
fig, axs = plt.subplots(2, 2, figsize=(14, 8))

# Ajustar los espaciados entre los subgráficos
plt.subplots_adjust(wspace=0.3, hspace=0.4)

# Agregar un título general a los subgráficos
fig.suptitle('Ventas en el periodo de enero a diciembre de 2022 en las tiendas A, B, C y D', fontsize=20)

# Lista de colores
colores = ['darkviolet', 'green', 'darkblue', 'coral']

# Bucle para trazar y personalizar los subgráficos
for i, ax in enumerate(axs.flat):
    ax.plot(ventas_tiendas.loc[ventas_tiendas.index[i]], color=colores[i], lw=3)
    ax.set_title(f'Ventas en la tienda {ventas_tiendas.index[i]}', loc='left', fontsize=16)
    ax.set_xlabel('Mes', fontsize=14)
    ax.set_ylabel('Número de ventas', fontsize=14)
    ax.tick_params(labelsize=12)
    ax.grid(color='lightgrey')
